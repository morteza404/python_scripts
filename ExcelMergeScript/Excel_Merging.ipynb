# %%
import os
import pandas as pd

# %%
path = os.getcwd()
files = os.listdir(path)
files
# Out:
# ['.ipynb_checkpoints',
#  'excel_files',
#  'Excel_Merging.ipynb',
#  'Excel_Merging.pdf',
#  'iot_top_blogs.xlsx',
#  'Top_Tech_blogs.xlsx']

# %%
files_xlsx = [f for f in files if f[-4:]=='xlsx']
files_xlsx
# Out:
# ['iot_top_blogs.xlsx', 'Top_Tech_blogs.xlsx']

# %%
df = pd.DataFrame()

# %%
for f in files_xlsx:
    data = pd.read_excel(f)
    df = df.append(data)
# Out:
# C:\anaconda\lib\site-packages\pandas\core\frame.py:6201: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   sort=sort)

# %%
df
# Out:
#    FeedDemon  Unnamed: 4                       Unnamed: 5  \
# 0        YES         NaN                              NaN
# 1        YES         NaN                              NaN
# 2         NO         NaN                      google news
# 3         NO         NaN                       iot reddit
# 4        YES         NaN                      iot central
# 5        YES         NaN  https://iot.ieee.org/newsletter
# 6        YES         NaN                              NaN
# 7         NO         NaN                              NaN
# 8         NO         NaN                              NaN
# 9         NO         NaN                              NaN
# 10        NO         NaN                              NaN
# 11        NO         NaN                              NaN
# 12       YES         NaN                              NaN
# 13       YES         NaN                              NaN
# 14        NO         NaN                              NaN
# 15        NO         NaN                              NaN
# 16        NO         NaN                              NaN
# 17        NO         NaN                              NaN
# 18       YES         NaN                              NaN
# 19        NO         NaN                              NaN
# 20       YES         NaN                              NaN
# 21       YES         NaN                              NaN
# 22       YES         NaN                              NaN
# 23       YES         NaN                              NaN
# 24       YES         NaN                              NaN
# 25       YES         NaN                              NaN
# 26        NO         NaN                              NaN
# 27       YES         NaN                              NaN
# 28       YES         NaN                              NaN
# 29        NO         NaN                              NaN
# ..       ...         ...                              ...
# 7        NaN         NaN                              NaN
# 8        NaN         NaN                              NaN
# 9        NaN         NaN                              NaN
# 10       NaN         NaN                              NaN
# 11       NaN         NaN                              NaN
# 12       NaN         NaN                              NaN
# 13       NaN         NaN                              NaN
# 14       NaN         NaN                              NaN
# 15       NaN         NaN                              NaN
# 16       NaN         NaN                              NaN
# 17       NaN         NaN                              NaN
# 18       NaN         NaN                              NaN
# 19       NaN         NaN                              NaN
# 20       NaN         NaN                              NaN
# 21       NaN         NaN                              NaN
# 22       NaN         NaN                              NaN
# 23       NaN         NaN                              NaN
# 24       NaN         NaN                              NaN
# 25       NaN         NaN                              NaN
# 26       NaN         NaN                              NaN
# 27       NaN         NaN                              NaN
# 28       NaN         NaN                              NaN
# 29       NaN         NaN                              NaN
# 30       NaN         NaN                              NaN
# 31       NaN         NaN                              NaN
# 32       NaN         NaN                              NaN
# 33       NaN         NaN                              NaN
# 34       NaN         NaN                              NaN
# 35       NaN         NaN                              NaN
# 36       NaN         NaN                              NaN
#
#                                    address                               name  \
# 0                                      NaN                                NaN
# 1                                      NaN                                NaN
# 2                                      NaN                                NaN
# 3                                      NaN                                NaN
# 4                                      NaN                                NaN
# 5                                      NaN                                NaN
# 6                                      NaN                                NaN
# 7                                      NaN                                NaN
# 8                                      NaN                                NaN
# 9                                      NaN                                NaN
# 10                                     NaN                                NaN
# 11                                     NaN                                NaN
# 12                                     NaN                                NaN
# 13                                     NaN                                NaN
# 14                                     NaN                                NaN
# 15                                     NaN                                NaN
# 16                                     NaN                                NaN
# 17                                     NaN                                NaN
# 18                                     NaN                                NaN
# 19                                     NaN                                NaN
# 20                                     NaN                                NaN
# 21                                     NaN                                NaN
# 22                                     NaN                                NaN
# 23                                     NaN                                NaN
# 24                                     NaN                                NaN
# 25                                     NaN                                NaN
# 26                                     NaN                                NaN
# 27                                     NaN                                NaN
# 28                                     NaN                                NaN
# 29                                     NaN                                NaN
# ..                                     ...                                ...
# 7                  bbc.com/news/technology              BBC News » Technology
# 8             washingtonpost.com/business/   The Washington Post » Technology
# 9                  businessinsider.com/sai            Tech | Business Insider
# 10               abcnews.go.com/Technology              ABC News » Technology
# 11                       theregister.co.uk                       The Register
# 12                                geek.com                           Geek.com
# 13                    https://gizmodo.com/                            Gizmodo
# 14               https://www.theverge.com/                          The Verge
# 15                 https://hackernoon.com/                        Hacker Noon
# 16              https://www.cnet.com/news/                               CNET
# 17          https://www.technewsworld.com/                      TechNewsWorld
# 18                 https://thenextweb.com/                       The Next Web
# 19                   http://www.wired.com/                          Wired.com
# 20              http://tech.firstpost.com/                              Tech2
# 21                    http://mashable.com/                           Mashable
# 22           http://www.digitaltrends.com/                      DigitalTrends
# 23               http://www.techradar.com/                          TechRadar
# 24                             hackster.io                           Hackster
# 25                 https://www.iotone.com/                             IoTOne
# 26              https://www.iotforall.com/                        IoT For All
# 27          https://www.iot-now.com/blogs/                            IoT Now
# 28              https://iot-analytics.com/                      IoT Analytics
# 29            https://www.iottechexpo.com/         IoT Tech Expo World Series
# 30  https://www.iotevolutionworld.com/iot/                IoT Evolution World
# 31            https://www.iottechnews.com/                      IoT Tech News
# 32     https://www.theinternetofthings.eu/                 Internet Of Things
# 33            https://iotbusinessnews.com/                  IoT Business News
# 34              https://blog.thethings.io/                       Thethings.io
# 35         https://www.iotcentral.io/blog/                        IoT Central
# 36             http://iiot-world.com/news/                         IIoT World
#
#     row                         source  \
# 0     1                      Readwrite
# 1     2                   The Guardian
# 2     3                  IOT Tech News
# 3     4                       McKinsey
# 4     5                The IOT Council
# 5     6                            IBM
# 6     7                  IOT Tech Expo
# 7     8                        Gartner
# 8     9                         Forbes
# 9    10                            IDC
# 10   11                   ABI research
# 11   12          TechTarget IoT Agenda
# 12   13                 Industrial IoT
# 13   14                Connected World
# 14   15                Businessinsider
# 15   16                 Marketresearch
# 16   17              Frost and Solivan
# 17   18                    IOT Journal
# 18   19        IEEE Internet of Things
# 19   20   Internet of things Institute
# 20   21  Internet of Things Consortium
# 21   22        IOT Security Foundation
# 22   23              IOT Business News
# 23   24                IOT Weekly News
# 24   25                Tech News World
# 25   26                      IoT World
# 26   27                  IoT Evolution
# 27   28                         IoTNow
# 28   29   Internet of Things Institute
# 29   30                       LinkLabs
# ..  ...                            ...
# 7     8                            NaN
# 8     9                            NaN
# 9    10                            NaN
# 10   11                            NaN
# 11   12                            NaN
# 12   13                            NaN
# 13   14                            NaN
# 14   15                            NaN
# 15   16                            NaN
# 16   17                            NaN
# 17   18                            NaN
# 18   19                            NaN
# 19   20                            NaN
# 20   21                            NaN
# 21   22                            NaN
# 22   23                            NaN
# 23   24                            NaN
# 24   25                            NaN
# 25   26                            NaN
# 26   27                            NaN
# 27   28                            NaN
# 28   29                            NaN
# 29   30                            NaN
# 30   31                            NaN
# 31   32                            NaN
# 32   33                            NaN
# 33   34                            NaN
# 34   35                            NaN
# 35   36                            NaN
# 36   37                            NaN
#
#                                              web_site
# 0                               https://readwrite.com
# 1   https://www.theguardian.com/technology/interne...
# 2                        https://www.iottechnews.com/
# 3   https://www.mckinsey.com/featured-insights/int...
# 4                  https://www.theinternetofthings.eu
# 5       https://www.ibm.com/blogs/internet-of-things/
# 6                        https://www.iottechexpo.com/
# 7                             https://www.gartner.com
# 8                              https://www.forbes.com
# 9                                 https://www.idc.com
# 10  https://www.abiresearch.com/market-research/se...
# 11      http://internetofthingsagenda.techtarget.com/
# 12                        https://industrial-iot.com/
# 13                   https://connectedworld.com/blog/
# 14                    https://www.businessinsider.com
# 15                             www.marketresearch.com
# 16                                      ww2.frost.com
# 17                         http://www.iotjournal.com/
# 18                              http://ieee-iotj.org/
# 19                               http://www.ioti.com/
# 20                             https://iofthings.org/
# 21        https://www.iotsecurityfoundation.org/blog/
# 22                       https://iotbusinessnews.com/
# 23                          http://iotweeklynews.com/
# 24  https://www.technewsworld.com/perl/section/int...
# 25         http://internetofthingsworld.com/iot-news/
# 26                  http://www.iotevolutionworld.com/
# 27                      https://www.iot-now.com/news/
# 28              http://www.ioti.com/news-and-analysis
# 29  https://www.link-labs.com/blog/topic/internet-...
# ..                                                ...
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
#
# [81 rows x 8 columns]

# %%
df.to_excel('merged.xlsx')
